# %% [markdown]
# ## Python +selenium +chrome drive

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import re
import pandas as pd
from tabulate import tabulate
import os

#launch url
url = "http://www.askart.com/index.aspx"


driver = webdriver.Chrome("/usr/local/bin/chromedriver")
driver.implicitly_wait(30)
driver.get(url)
soup_level1=BeautifulSoup(driver.page_source, 'lxml')

# %%
driver.find_element_by_id('MainPageContent_txtArtistName').send_keys("Edgar Degas")

# %%
#import time
#time.sleep(2)

# %%
auto_complete = driver.find_elements_by_xpath(
        "//li[contains(@class, 'ui-menu-item')]")
auto_complete[0].click()

# %%
#driver.find_element_by_id('MainPageContent_searchButton').click()

# %%
driver.find_element_by_xpath('//span[contains(@class,"noUnderlineTOCitem") and contains(text(), "Auction Records")]').click()

# %%
selection = driver.find_elements_by_xpath('//div[@class="selectize-input items full has-options has-items"]')[0]
selection.click()

# %%
selection2 = driver.find_element_by_xpath('//div[@data-value="Painting"]').click()

# %%
Title_list=[]
Hammer_Price=[]
Low_Estimate_price=[]
High_Estimate_price=[]
Signature_list=[]
Size=[]
created_date=[]
Medium=[]
Auction_Lot=[]
Auction_House=[]
Auction_Date=[]

# %%
x=0
while x < 19:
    try:
        soup_level1=BeautifulSoup(driver.page_source, 'lxml')
        for link in soup_level1.find_all('div',attrs={"class":"PriceBox"}):
     #print(link.text)
                Title_list.append(link.contents[2].text) 
                Hammer_Price.append(link.contents[6])
                Low_Estimate_price.append(link.contents[11])
                High_Estimate_price.append(link.contents[14])
                if link.contents[21].string == "Signature:":
                    Signature_list.append(link.contents[22])
                else:
                    Signature_list.append("Unavailable")
               
                
                if link.contents[26].string == None:    
                    Size.append(link.contents[27])
                else:    
                    Size.append(link.contents[24])    
                     
                if  link.contents[29].string == "Created:":   
                    created_date.append(link.contents[30].string)#28
                elif (link.contents[29].string) == "Medium:\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0":  
                    created_date.append(link.contents[27].string)
                else:  
                    if link.contents[31].string != None:
                        created_date.append(link.contents[31].string)
                    else:
                        created_date.append(link.contents[28].string)
               
                   
                if link.contents[33].string == "Medium:\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0": 
                    Medium.append(link.contents[34].string)
                elif link.contents[33].string == "Auction Lot:":
                    Medium.append(link.contents[30].string)
                else:
                    Medium.append(link.contents[33].string)
                
                if link.contents[36].string =="Auction Lot:":  
                    Auction_Lot.append(link.contents[37].string)
                else:    
                    Auction_Lot.append(link.contents[34].string)
                
                if (link.contents[41].string) == None:
                    Auction_House.append(link.contents[42].string)
                else:
                    if ((link.contents[41].string)) == "Auction House:":
                            Auction_House.append(link.contents[42].string)
                    elif (link.contents[41].string) == "Auction Date:": 
                            Auction_House.append(link.contents[39].string)
                    else:
                            Auction_House.append(link.contents[41].string)
                if link.contents[44].string == None:
                    Auction_Date.append(link.contents[42].string)
                else:
                    if (link.contents[44].string) == "Auction Date:":
                            Auction_Date.append(link.contents[45].string)
                
                    else:
                            Auction_Date.append(link.contents[44].string)
       
        driver.find_element_by_xpath('//div[@class="pagination BiggerPaginator"]//a[@class="next"]').click()
        x+=1  
    except:
        break
        print("The scraping has came to an end")

# %%
vdict={'Title':Title_list,
'Hammer_Price':Hammer_Price,
'Low_Estimate_price':Low_Estimate_price,
'High_Estimate_price':High_Estimate_price,
'Signature':Signature_list,
'Size':Size,
'created_date':created_date,
'Medium':Medium,
'Auction_Lot':Auction_Lot,
'Auction_House':Auction_House,
'Auction_Date':Auction_Date}

# %%
df = pd.DataFrame(vdict,columns =['Title',"Hammer_Price","Low_Estimate_price","High_Estimate_price","Signature","Size","created_date","Medium","Auction_Lot","Auction_House","Auction_Date"]) 
df
# Out:
#                                                  Title  \
# 0                                 DANSEUSES À LA BARRE
# 1                                       DEUX DANSEUSES
# 2                                     Femme s'essuyant
# 3                                Joseph-Gabriel Tourny
# 4                            Chanteuse de café-concert
# 5    Danseuses dans une salle d'exercice (Trois Dan...
# 6         FILLETTE PORTANT DES FLEURS DANS SON TABLIER
# 7                                         Tête d'homme
# 8                                    SCÈNE D'INTÉRIEUR
# 9                               PORTRAIT D'HOMME ASSIS
# 10                                           ITALIENNE
# 11                  Buste de danseuse au corsage rouge
# 12                                      Paul Valpinçon
# 13   Petites filles spartiates provoquant des garço...
# 14                                    Quatre danseuses
# 15                    Après le bain, trois femmes nues
# 16                                 FEMME À SA TOILETTE
# 17   A Standing Dancer, Her Hands Behind Her Back (...
# 18   Deux femmes appuyées à une barrière (Conversat...
# 19                               Arlequin et danseuses
# 20            TROIS DANSEUSES DEBOUT PRÈS D'UN PORTANT
# 21                         Femme assise dans un jardin
# 22         Étude d'après Luca della Robbia, "Cantoria"
# 23                                              JOCKEY
# 24                 FEMME EN PEIGNOIR ROUGE SE COIFFANT
# 25                      DANSEUSE RAJUSTANT SA COIFFURE
# 26                          Pelouse et route sous-bois
# 27                                  Dans les coulisses
# 28                                        DEUX JOCKEYS
# 29                                     TROIS DANSEUSES
# ..                                                 ...
# 95                                       Après le bain
# 96                                             Paysage
# 97                                        TÊTE D'HOMME
# 98                            Danseuses et contrebasse
# 99                 Nu assis, les jambes croisées, 1880
# 100                           LA PROMENADE DES CHEVAUX
# 101  Jeune fille assise appuyée au dossier d'un fau...
# 102                                       FEMME DEBOUT
# 103                         PORTRAIT DE MME ERNEST MAY
# 104                             DEUX DANSEUSES ASSISES
# 105                                    LA CONVERSATION
# 106                                     BUSTE DE FEMME
# 107                                   Femme s'essuyant
# 108                         FEMME S'ESSUYANT LES PIEDS
# 109                            DEUX DANSEUSES AU FOYER
# 110                                Femme à sa toilette
# 111                             PAYSAGE, EFFET DU SOIR
# 112                  FEMME TENANT UN CHAPEAU À LA MAIN
# 113                                  FEMME SE PEIGNANT
# 114  Etude d'après La Sibylle de Delphe (recto); an...
# 115                                          DANSEUSES
# 116                   AU CAFÉ-CONCERT, DEUX CHANTEUSES
# 117                             Plage à la marée basse
# 118                                Cavalier et amazone
# 119           ÉTUDE DE NU POUR UNE DANSEUSE À LA BARRE
# 120                                     Marée montante
# 121                                     FEMMES AU BAIN
# 122                   APRÈS LE BAIN (FEMME S'ESSUYANT)
# 123                    DANSEUSE RAJUSTANT SON CHAUSSON
# 124  JEUNE HOMME, VU DE PROFIL: COPIE D'APRES "LES ...
#
#                         Hammer_Price                 Low_Estimate_price  \
# 0                                                  <b>Low Estimate:</b>
# 1                                                  <b>Low Estimate:</b>
# 2                                                  <b>Low Estimate:</b>
# 3                         -not sold-                 $92,850  (€80,000)
# 4                         -not sold-               $232,120  (€200,000)
# 5           $5,484,610  (£4,178,750)             $1,050,000  (£800,000)
# 6               $262,500  (£200,000)               $131,250  (£100,000)
# 7                         -not sold-                           $350,000
# 8                           $225,000                           $250,000
# 9                         -not sold-                           $300,000
# 10                           $43,750                            $40,000
# 11                        -not sold-                           $200,000
# 12                        -not sold-                           $120,000
# 13                        $1,452,500                           $400,000
# 14                        $5,937,500                         $5,000,000
# 15              $483,980  (£368,750)               $393,750  (£300,000)
# 16              $958,130  (£730,000)               $656,250  (£500,000)
# 17              $272,510  (€234,800)               $232,120  (€200,000)
# 18                        $2,292,500                         $3,000,000
# 19                        -not sold-                         $2,000,000
# 20                        -not sold-                           $700,000
# 21                        $1,452,500                         $1,000,000
# 22                $31,920  (€27,500)                 $23,210  (€20,000)
# 23              $595,390  (€513,000)               $232,120  (€200,000)
# 24                        -not sold-               $464,240  (€400,000)
# 25                        -not sold-               $196,880  (£150,000)
# 26                $95,160  (£72,500)                 $65,630  (£50,000)
# 27         $11,804,300  (£8,993,750)          $10,500,000  (£8,000,000)
# 28                          $350,000                            $80,000
# 29                        $1,575,000                           $900,000
# ..                               ...                                ...
# 95                          $122,500                            $40,000
# 96                           $68,750                            $70,000
# 97                          $425,000                           $350,000
# 98                          $485,000                           $400,000
# 99                  not communicated               $464,030  (€350,000)
# 100                       -not sold-               $232,130  (£150,000)
# 101             $653,820  (£422,500)               $619,000  (£400,000)
# 102             $449,550  (£290,500)               $278,550  (£180,000)
# 103                         $461,000                            $60,000
# 104                       $5,205,000                         $3,000,000
# 105                       -not sold-                         $3,500,000
# 106                       -not sold-                           $800,000
# 107                       -not sold-                         $3,000,000
# 108         $2,727,470  (£1,762,500)           $1,547,500  (£1,000,000)
# 109             $783,810  (£506,500)               $773,750  (£500,000)
# 110             $449,550  (£290,500)               $386,880  (£250,000)
# 111               $54,160  (£35,000)                 $46,430  (£30,000)
# 112             $783,810  (£506,500)               $309,500  (£200,000)
# 113                       $1,085,000                           $900,000
# 114                       -not sold-                            $15,000
# 115         $2,760,960  (£1,762,500)           $2,819,700  (£1,800,000)
# 116                       -not sold-               $391,630  (£250,000)
# 117              $134,520  (£85,875)                 $47,000  (£30,000)
# 118    $185,070  (S. KRONA1,220,000)      $182,040  (S. KRONA1,200,000)
# 119                         $545,000                           $400,000
# 120               $86,500  (£55,250)                 $78,290  (£50,000)
# 121                       -not sold-               $550,480  (£350,000)
# 122        $12,212,480  (£7,769,250)           $3,929,750  (£2,500,000)
# 123         $7,106,950  (£4,521,250)           $4,715,700  (£3,000,000)
# 124                          $47,500                            $15,000
#
#                   High_Estimate_price                      Signature  \
# 0               <b>High Estimate:</b>                    Unavailable
# 1               <b>High Estimate:</b>                    Unavailable
# 2               <b>High Estimate:</b>                    Unavailable
# 3                $139,270  (€120,000)                         Signed
# 4                $348,180  (€300,000)                         Signed
# 5            $1,575,000  (£1,200,000)                         Signed
# 6                $196,880  (£150,000)                        Stamped
# 7                            $450,000                        Stamped
# 8                            $350,000                        Stamped
# 9                            $500,000                    Unavailable
# 10                            $60,000                      Inscribed
# 11                           $300,000                        Stamped
# 12                           $180,000                    Unavailable
# 13                           $600,000                        Stamped
# 14                         $7,000,000              Signed Lower Left
# 15               $525,000  (£400,000)                        Stamped
# 16               $918,750  (£700,000)                        Stamped
# 17               $348,180  (€300,000)                        Stamped
# 18                         $5,000,000              Signed Lower Left
# 19                         $4,000,000                         Signed
# 20                         $1,000,000                        Stamped
# 21                         $1,500,000                    Unavailable
# 22                 $34,820  (€30,000)                    Unavailable
# 23               $348,180  (€300,000)                        Stamped
# 24               $696,360  (€600,000)                        Stamped
# 25               $262,500  (£200,000)                        Stamped
# 26                $105,000  (£80,000)                        Stamped
# 27         $15,750,000  (£12,000,000)              Signed Lower Left
# 28                           $120,000                        Stamped
# 29                         $1,200,000                        Stamped
# ..                                ...                            ...
# 95                            $60,000                        Stamped
# 96                           $100,000                    Unavailable
# 97                           $450,000                        Stamped
# 98                           $600,000              Signed Lower Left
# 99               $662,900  (€500,000)             Signed Lower Right
# 100              $386,880  (£250,000)                        Stamped
# 101              $928,500  (£600,000)                        Stamped
# 102              $386,880  (£250,000)                    Unavailable
# 103                           $80,000             Signed Lower Right
# 104                        $5,000,000                        Stamped
# 105                        $5,000,000               Signed and Dated
# 106                        $1,200,000                         Signed
# 107                        $5,000,000             Signed Lower Right
# 108          $2,321,250  (£1,500,000)                        Stamped
# 109            $1,083,250  (£700,000)                        Stamped
# 110              $541,630  (£350,000)                    Unavailable
# 111                $61,900  (£40,000)                    Unavailable
# 112              $464,250  (£300,000)                        Stamped
# 113                        $1,200,000              Signed Lower Left
# 114                           $20,000                    Unavailable
# 115          $3,916,250  (£2,500,000)                         Signed
# 116              $548,280  (£350,000)                        Stamped
# 117                $78,330  (£50,000)                        Stamped
# 118     $227,550  (S. KRONA1,500,000)                        Stamped
# 119                          $600,000             Signed Lower Right
# 120               $109,600  (£70,000)                        Stamped
# 121              $707,760  (£450,000)                        Stamped
# 122          $5,501,650  (£3,500,000)                        Stamped
# 123          $7,859,500  (£5,000,000)                        Stamped
# 124                           $20,000                        Stamped
#
#                                                   Size  \
# 0                                                <br/>
# 1                                                <br/>
# 2                                                <br/>
# 3                                   (21.90cm x 18.4...
# 4                                   (25.70cm x 19.2...
# 5                                   (27.50cm x 22.7...
# 6                                   (73.30cm x 55.7...
# 7                                   (31.12cm x 23.8...
# 8                                   (52.07cm x 33.3...
# 9                                   (37.47cm x 29.8...
# 10                                  (28.27cm x 14.6...
# 11                                  (41.28cm x 21.9...
# 12                                  (32.39cm x 24.4...
# 13                                  (49.86cm x 32.0...
# 14                                  (78.74cm x 88.9...
# 15                                  (63.60cm x 80.5...
# 16                                  (41.30cm x 32.0...
# 17                                  (47.00cm x 39.5...
# 18                                  (52.07cm x 66.6...
# 19                                  (34.62cm x 46.6...
# 20                                  (70.82cm x 57.7...
# 21                                  (33.02cm x 40.6...
# 22                                  (21.00cm x 23.0...
# 23                                  (31.50cm x 23.5...
# 24                                  (56.60cm x 68.2...
# 25                                  (56.00cm x 36.0...
# 26                                  (32.50cm x 49.7...
# 27                                  (66.70cm x 37.5...
# 28                                  (23.83cm x 31.1...
# 29                                  (44.78cm x 49.8...
# ..                                                 ...
# 95                                  (70.18cm x 52.7...
# 96                                  (26.67cm x 44.1...
# 97                                  (31.12cm x 23.8...
# 98                                  (22.86cm x 17.1...
# 99                                  (35.00cm x 27.0...
# 100                                 (25.00cm x 31.0...
# 101                                 (70.20cm x 49.2...
# 102                                 (47.40cm x 29.9...
# 103                                 (44.45cm x 29.5...
# 104                                 (67.64cm x 102....
# 105                                 (65.10cm x 49.8...
# 106                                 (54.61cm x 35.5...
# 107                                 (103.51cm x 83....
# 108                                 (45.70cm x 58.0...
# 109                                 (52.00cm x 44.5...
# 110                                 (69.50cm x 79.0...
# 111                                 (19.30cm x 31.2...
# 112                                 (48.80cm x 63.6...
# 113                                 (49.53cm x 38.1...
# 114                                 (30.48cm x 24.7...
# 115                                 (63.00cm x 42.0...
# 116                                 (47.50cm x 45.5...
# 117                                 (27.40cm x 39.8...
# 118                                 (31.00cm x 22.0...
# 119                                 (119.08cm x 86....
# 120                                 (23.50cm x 31.5...
# 121                                 (57.40cm x 81.6...
# 122                                 (72.00cm x 58.0...
# 123                                 (50.00cm x 62.5...
# 124                                 (34.93cm x 30.4...
#
#                     created_date  \
# 0                     c. 1883-85
# 1                         c.1891
# 2                        c. 1899
# 3                           1872
# 4                      not given
# 5                      not given
# 6                     c. 1860-62
# 7                        c. 1864
# 8                        c. 1867
# 9                     c. 1864-68
# 10                       c. 1856
# 11                          1899
# 12                  c. 1868-1872
# 13                          1860
# 14                       c. 1903
# 15                     c.1890-95
# 16                       c. 1897
# 17                          1887
# 18                   c 1882-1885
# 19                          1884
# 20                       c. 1900
# 21                       1872-73
# 22                        c.1856
# 23                    c. 1881-85
# 24                       c. 1889
# 25                       c. 1900
# 26                     c.1890-93
# 27                  C. 1882-1885
# 28                     c 1868-70
# 29                       c. 1889
# ..                           ...
# 95                        c.1903
# 96                       1880-85
# 97                        c.1864
# 98                     c.1879-80
# 99                          1880
# 100                 c. 1881-1885
# 101                       c.1889
# 102                      1870-72
# 103                      1881-82
# 104                         1896
# 105                         1895
# 106                    c.1887-90
# 107                  c.1905-1907
# 108                       c.1893
# 109                       c.1898
# 110                    not given
# 111                    1857-1858
# 112                      c. 1885
# 113                    not given
# 114                    c.1855-56
# 115                      c. 1896
# 116                   c. 1878-80
# 117                    not given
# 118                    not given
# 119                    c.1895-98
# 120                      c. 1869
# 121                    c.1890-95
# 122                    c.1882-85
# 123                         1887
# 124                    not given
#
#                                                 Medium  \
# 0      Pastel  and charcoal on paper laid down on card
# 1    Pastel  ,on joined paper mounted on card laid ...
# 2    Pastel  on paper laid down on card laid down o...
# 3                    Oil  on paper laid down on canvas
# 4                         Pastel  over montype / Paper
# 5                                         Oil / Canvas
# 6                                         Oil / Canvas
# 7                                Oil / Canvas on board
# 8                                          Oil / Board
# 9                                         Oil / Canvas
# 10                                  Watercolor / Paper
# 11    Pastel  pastel on joined paper laid down on card
# 12          Oil  on paper laid down on canvas / Canvas
# 13                               Oil / Canvas on board
# 14                     Pastel  paper laid down on card
# 15                                      Pastel / Paper
# 16   Pastel  on joined sheets of paper laid down on...
# 17                        Pastel  and charcoal / Paper
# 18                                      Pastel / Paper
# 19                                      Pastel / Paper
# 20                         Pastel  and charcoal / Card
# 21                                        Oil / Canvas
# 22                        Oil  on paper laid on canvas
# 23                        Pastel  and charcoal / Paper
# 24   Pastel  , charcoal, stumping and black crayon ...
# 25               Pastel  and charcoal / Paper on board
# 26                                      Pastel / Paper
# 27                                      Pastel / Linen
# 28                            Gouache  and oil / Paper
# 29                Pastel  , charcoal and chalk / Paper
# ..                                                 ...
# 95                  Pastel  over counter-proof / Paper
# 96                             Pastel / Paper on board
# 97                                   Oil / Canvasboard
# 98                                         Oil / Panel
# 99                                         Oil / Panel
# 100                       Pastel  and charcoal / Paper
# 101                                        Oil / Panel
# 102                                    Gouache / Paper
# 103                                     Pastel / Paper
# 104                                    Pastel / Canvas
# 105                                     Pastel / Paper
# 106                                       Oil / Canvas
# 107                    Pastel  on joined paper / Board
# 108                            Pastel / Paper on board
# 109                                     Pastel / Paper
# 110                       Pastel  and charcoal / Paper
# 111                                        Oil / Paper
# 112                                     Pastel / Paper
# 113                                     Pastel / Paper
# 114                        Gouache  and pencil / Paper
# 115                                     Pastel / Paper
# 116                       Pastel  and charcoal / Paper
# 117                                     Pastel / Paper
# 118                                     Pastel / Paper
# 119              Pastel  and charcoal / Paper on board
# 120                                     Pastel / Paper
# 121                                     Pastel / Paper
# 122                            Pastel / Paper on board
# 123                                     Pastel / Paper
# 124                      Watercolor and pencil / Paper
#
#                                            Auction_Lot  \
# 0      Pastel  and charcoal on paper laid down on card
# 1    Pastel  ,on joined paper mounted on card laid ...
# 2    Pastel  on paper laid down on card laid down o...
# 3                                                  219
# 4                                                   30
# 5                                                   24
# 6                                                  349
# 7                                                  523
# 8                                                  138
# 9                                                  431
# 10                                                 444
# 11                                                 178
# 12                                                 279
# 13                                                 406
# 14                                                 46A
# 15                                                 174
# 16                                                  36
# 17                                                  10
# 18                                                 10A
# 19                                                 39A
# 20                                                 145
# 21                                                 516
# 22                                                 282
# 23                                                   2
# 24                                                   5
# 25                                                 175
# 26                                                 257
# 27                                                  20
# 28                                                  25
# 29                                                  19
# ..                                                 ...
# 95                                                 131
# 96                                                 138
# 97                                                 122
# 98                                                  22
# 99                                                   1
# 100                                                138
# 101                                                371
# 102                                                146
# 103                                                213
# 104                                                 42
# 105                                                 49
# 106                                                 68
# 107                                                 22
# 108                                                  3
# 109                                                 87
# 110                                                209
# 111                                                444
# 112                                                  2
# 113                                                 34
# 114                                                 63
# 115                                                 62
# 116                                                 64
# 117                                                170
# 118                                               2068
# 119                                                468
# 120                                                294
# 121                                                320
# 122                                                 13
# 123                                                 19
# 124                                                 52
#
#                                Auction_House  \
# 0
# 1
# 2
# 3                           Christie's Paris
# 4                           Christie's Paris
# 5             Christie's London, King Street
# 6          Sotheby's London, New Bond Street
# 7    Christie's New York, Rockefeller Center
# 8                         Sotheby's New York
# 9                         Sotheby's New York
# 10                        Sotheby's New York
# 11   Christie's New York, Rockefeller Center
# 12   Christie's New York, Rockefeller Center
# 13   Christie's New York, Rockefeller Center
# 14   Christie's New York, Rockefeller Center
# 15            Christie's London, King Street
# 16         Sotheby's London, New Bond Street
# 17                         Dorotheum, Vienna
# 18   Christie's New York, Rockefeller Center
# 19   Christie's New York, Rockefeller Center
# 20                        Sotheby's New York
# 21   Christie's New York, Rockefeller Center
# 22                          Christie's Paris
# 23                           Sotheby's Paris
# 24                           Sotheby's Paris
# 25         Sotheby's London, New Bond Street
# 26            Christie's London, King Street
# 27            Christie's London, King Street
# 28                        Sotheby's New York
# 29                        Sotheby's New York
# ..                                       ...
# 95   Christie's New York, Rockefeller Center
# 96   Christie's New York, Rockefeller Center
# 97                        Sotheby's New York
# 98                          Bonhams New York
# 99                              Tajan, Paris
# 100           Christie's London, King Street
# 101           Christie's London, King Street
# 102        Sotheby's London, New Bond Street
# 103                       Sotheby's New York
# 104                       Sotheby's New York
# 105                       Sotheby's New York
# 106                       Sotheby's New York
# 107  Christie's New York, Rockefeller Center
# 108        Sotheby's London, New Bond Street
# 109        Sotheby's London, New Bond Street
# 110           Christie's London, King Street
# 111           Christie's London, King Street
# 112           Christie's London, King Street
# 113                       Sotheby's New York
# 114              09/12/2013
#
# 115        Sotheby's London, New Bond Street
# 116        Sotheby's London, New Bond Street
# 117           Christie's London, King Street
# 118                   Stockholm Auktionsverk
# 119                       Sotheby's New York
# 120           Christie's London, King Street
# 121        Sotheby's London, New Bond Street
# 122        Sotheby's London, New Bond Street
# 123        Sotheby's London, New Bond Street
# 124                       Sotheby's New York
#
#                                     Auction_Date
# 0                    05/15/2019
#
# 1                    05/14/2019
#
# 2                                           None
# 3                    03/29/2019
#
# 4                    03/28/2019
#
# 5                    02/27/2019
#
# 6                    02/27/2019
#
# 7                    11/14/2018
#
# 8                    11/13/2018
#
# 9                    11/13/2018
#
# 10                   11/13/2018
#
# 11                   11/12/2018
#
# 12                   11/12/2018
#
# 13                   11/12/2018
#
# 14                   11/11/2018
#
# 15                   06/21/2018
#
# 16                   06/19/2018
#
# 17                   05/15/2018
#
# 18                   05/15/2018
#
# 19                   05/15/2018
#
# 20                   05/15/2018
#
# 21                   05/10/2018
#
# 22                   03/23/2018
#
# 23                   03/22/2018
#
# 24                   03/22/2018
#
# 25                   03/01/2018
#
# 26                   02/28/2018
#
# 27                   02/27/2018
#
# 28                   01/31/2018
#
# 29                   11/14/2017
#
# ..                                           ...
# 95                   11/06/2014
#
# 96                   11/06/2014
#
# 97                   11/05/2014
#
# 98                   11/04/2014
#
# 99                   07/28/2014
#
# 100                  06/25/2014
#
# 101                  06/25/2014
#
# 102                  06/24/2014
#
# 103                  05/08/2014
#
# 104                  05/07/2014
#
# 105                  05/07/2014
#
# 106                  05/07/2014
#
# 107                  05/06/2014
#
# 108                  02/05/2014
#
# 109                  02/05/2014
#
# 110                  02/05/2014
#
# 111                  02/05/2014
#
# 112                  02/04/2014
#
# 113                  11/06/2013
#
# 114                See all lots for this auction
# 115                  06/19/2013
#
# 116                  06/19/2013
#
# 117                  06/19/2013
#
# 118       06/04/2013-06/06/2013
#
# 119                  05/08/2013
#
# 120                  02/07/2013
#
# 121                  02/06/2013
#
# 122                  02/05/2013
#
# 123                  02/05/2013
#
# 124       01/29/2013-01/30/2013
#
#
# [125 rows x 11 columns]

# %% [markdown]
# # Cleaning process for null, incomplete and inregular value

# %%
df=df.fillna("0")

# %%
houselist=[]

# %%
driver.find_element_by_xpath('//div[@class="pagination BiggerPaginator"]//a[@class="first"]').click()

# %%
x=0
while x < 19:
    try:
            soup_level1=BeautifulSoup(driver.page_source, 'lxml')
            for link in soup_level1.find_all('div',attrs={"class":"PriceBox"}):
                if link.contents[38].string != None:  
                    houselist.append(link.contents[38].string)
          
            driver.find_element_by_xpath('//div[@class="pagination BiggerPaginator"]//a[@class="next"]').click()
            x+=1  
    except:
            break
            print("The scraping has came to an end")

# %%
df["High_Estimate_price"]=df["High_Estimate_price"].replace('\(([^()]|())*\)', '',regex=True)
df["Low_Estimate_price"]=df["Low_Estimate_price"].replace('\(([^()]|())*\)', '',regex=True)
df["Title"]=df["Title"].replace('\(([^()]|())*\)', '',regex=True)

# %%
df["Low_Estimate_price"]=df["Low_Estimate_price"].str.replace('$', '')
df["Low_Estimate_price"]=df["Low_Estimate_price"].str.replace(',', '')
df["Low_Estimate_price"]=df["Low_Estimate_price"].str.replace('n/a', '0')
df["Low_Estimate_price"]=df["Low_Estimate_price"].str.replace('\xa0', '')

# %%
df["High_Estimate_price"]=df["High_Estimate_price"].str.replace('$', '')
df["High_Estimate_price"]=df["High_Estimate_price"].str.replace(',', '')
df["High_Estimate_price"]=df["High_Estimate_price"].str.replace('n/a', '0')
df["High_Estimate_price"]=df["High_Estimate_price"].str.replace('\xa0', '')

# %%
df["created_date"]=df["created_date"].str.replace('c.', '')
df["created_date"]=df["created_date"].str.replace('. ', '')
df["created_date"]=df["created_date"].str.replace('.', '')
df["Auction_House"]=df["Auction_House"].str.replace('\xa0', '')
df["Hammer_Price"]=df["Hammer_Price"].replace('\(([^()]|())*\)', '',regex=True)

# %%
df["Hammer_Price"]=df["Hammer_Price"].str.replace('$', '')
df["Hammer_Price"]=df["Hammer_Price"].str.replace(',', '')

# %%
import numpy as np
for i in df.index:
      if df["Auction_House"][i] =='':
            print(i)

# %%
df=df.drop([59,176,738])

# %%
for i in df.index:
    if df["Auction_House"][i] is not np.nan: 
        if df["Auction_House"][i][-1]==' ':
            df["Auction_Date"][i]=df["Auction_House"][i]

# %%
for i in df.index:
      for e in range(len(houselist)):
        if df["Auction_House"][i] !='':
            if df["Auction_House"][i][-1]==' ':
                    df["Auction_House"][i]=houselist[e]

# %%
import collections

# %%
collections.Counter(df["Auction_House"])
# Out:
# Counter({'Artcurial': 1,
#          'Bonhams Bond Street': 1,
#          'Bonhams New York': 1,
#          "Christie's London, King Street": 17,
#          "Christie's New York, Rockefeller Center": 24,
#          "Christie's Paris": 4,
#          'Dorotheum, Vienna': 1,
#          'Giafferi': 1,
#          'Heritage Auctions': 1,
#          'Leclere Marseille': 1,
#          'Marambat de Malafosse': 1,
#          'Millon & Associes': 2,
#          "Sotheby's London, New Bond Street": 21,
#          "Sotheby's New York": 39,
#          "Sotheby's Paris": 5,
#          'Stockholm Auktionsverk': 1,
#          'Tajan, Paris': 1})

# %%
sold_status=[]

# %%
for i in df.index:
    if df["Hammer_Price"][i]=="-not sold-":
        sold_status.append("not sold")
    else:
        sold_status.append("sold")

# %%
df["sold_status"]=sold_status

# %%
df["Hammer_Price"]=df["Hammer_Price"].str.replace('-not sold-', '0')

# %%
for i in df.index:
     if df["Hammer_Price"][i] =='not communicated':
            df=df.drop([i])

# %%
for i in df.index:
     if df["Hammer_Price"][i]=="awaiting result":
            df=df.drop([i])

# %%
df["Hammer_Price"]=df["Hammer_Price"].str.replace('\xa0', '')
df["created_date"]=df["created_date"].str.replace('\xa0', '')
df["Medium"]=df["Medium"].str.replace('\xa0', '')

# %%
df["Size"]=df["Size"].str.replace(')', '')
df["Size"]=df["Size"].str.replace('(', '')
df["Size"]=df["Size"].str.replace('cm', '')
df["Size"]=df["Size"].str.replace('\xa0', '')

# %%
for i in df.index:
    if df["Medium"][i]== None:
         df=df.drop([i])

# %%
import numpy as np
for i in df.index:
    if df["Size"][i] is np.nan:
        df=df.drop([i])

# %%
#df=df.drop([331,1483,1549])

# %%
Width=[]
Height=[]

# %%
for i in df["Size"].str.split("x"):
        Width.append(i[0])
        Height.append(i[1])

# %%
df["height"]=Height
df["width"]=Width
df["width"]=df["width"].astype(float)
df["height"]=df["height"].astype(float)

# %%
df["Signature"]=df["Signature"].str.replace("\xa0","")
df["Auction_Date"]=df["Auction_Date"].str.replace("\xa0","")
df["Auction_Lot"]=df["Auction_Lot"].str.replace("\xa0","")

# %%
df=df.drop(["Size"],axis=1)

# %%
df.to_csv("Degas_auc.csv", index=False,encoding="utf-8")
