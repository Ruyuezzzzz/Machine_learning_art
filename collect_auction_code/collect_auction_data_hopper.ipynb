# %% [markdown]
# ## Python +selenium +chrome driver

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import re
import pandas as pd
from tabulate import tabulate
import os



url = "http://www.askart.com/auction_records/Edward_Hopper/24020/Edward_Hopper.aspx"


driver = webdriver.Chrome("/usr/local/bin/chromedriver")
driver.implicitly_wait(30)
driver.get(url)
soup_level1=BeautifulSoup(driver.page_source, 'lxml')

# %%
driver.find_element_by_id('MainPageContent_txtArtistName').send_keys("Edward Hopper")

# %%
#import time
#time.sleep(2)

# %%
auto_complete = driver.find_elements_by_xpath(
        "//li[contains(@class, 'ui-menu-item')]")
auto_complete[0].click()

# %%
#driver.find_element_by_id('MainPageContent_searchButton').click()

# %%
driver.find_element_by_xpath('//span[contains(@class,"noUnderlineTOCitem") and contains(text(), "Auction Records")]').click()

# %%
Title_list=[]
Hammer_Price=[]
Low_Estimate_price=[]
High_Estimate_price=[]
Signature_list=[]
Size=[]
created_date=[]
Medium=[]
Auction_Lot=[]
Auction_House=[]
Auction_Date=[]

# %%
x=0
while x < 12:
    try:
        soup_level1=BeautifulSoup(driver.page_source, 'lxml')
        for link in soup_level1.find_all('div',attrs={"class":"PriceBox"}):
     
                Title_list.append(link.contents[2].text) 
                Hammer_Price.append(link.contents[6])
                Low_Estimate_price.append(link.contents[11])
                High_Estimate_price.append(link.contents[14])
                if link.contents[21].string == "Signature:":
                    Signature_list.append(link.contents[22])
                else:
                    Signature_list.append("Unavailable")
                
                
                if link.contents[26].string == None:    
                    Size.append(link.contents[27])
                else:    
                    Size.append(link.contents[24])    
                     
                if  link.contents[29].string == "Created:":   
                    created_date.append(link.contents[30].string)#28
                elif (link.contents[29].string) == "Medium:\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0":  
                    created_date.append(link.contents[27].string)
                else:  
                    if link.contents[31].string != None:
                        created_date.append(link.contents[31].string)
                    else:
                        created_date.append(link.contents[28].string)
               
                   
                if link.contents[33].string == "Medium:\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0": 
                    Medium.append(link.contents[34].string)
                elif link.contents[33].string == "Auction Lot:":
                    Medium.append(link.contents[30].string)
                else:
                    Medium.append(link.contents[33].string)
                
                if link.contents[36].string =="Auction Lot:":  
                    Auction_Lot.append(link.contents[37].string)
                else:    
                    Auction_Lot.append(link.contents[34].string)
                
                if (link.contents[41].string) == None:
                    Auction_House.append(link.contents[42].string)
                else:
                    if ((link.contents[41].string)) == "Auction House:":
                            Auction_House.append(link.contents[42].string)
                    elif (link.contents[41].string) == "Auction Date:": 
                            Auction_House.append(link.contents[39].string)
                    else:
                            Auction_House.append(link.contents[41].string)
                if link.contents[44].string == None:
                    Auction_Date.append(link.contents[42].string)
                else:
                    if (link.contents[44].string) == "Auction Date:":
                            Auction_Date.append(link.contents[45].string)
                
                    else:
                            Auction_Date.append(link.contents[44].string)
       
        driver.find_element_by_xpath('//div[@class="pagination BiggerPaginator"]//a[@class="next"]').click()
        x+=1  
    except:
        break
        print("The scraping has came to an end")

# %%
vdict={'Title':Title_list,
'Hammer_Price':Hammer_Price,
'Low_Estimate_price':Low_Estimate_price,
'High_Estimate_price':High_Estimate_price,
'Signature':Signature_list,
'Size':Size,
'created_date':created_date,
'Medium':Medium,
'Auction_Lot':Auction_Lot,
'Auction_House':Auction_House,
'Auction_Date':Auction_Date}

# %%
df = pd.DataFrame(vdict,columns =['Title',"Hammer_Price","Low_Estimate_price","High_Estimate_price","Signature","Size","created_date","Medium","Auction_Lot","Auction_House","Auction_Date"]) 
df
# Out:
#                                                  Title  \
# 0                                            Windy Day
# 1                              STUDY FOR 'GIRLIE SHOW'
# 2                                        TWO COMEDIANS
# 3                              Cottages at North Truro
# 4                                            Chop Suey
# 5                             "Scarboro Bridge & Lake"
# 6                                      "STUDY OF FEET"
# 7                           STUDY FOR 'SUMMER EVENING'
# 8                       STUDY FOR 'A WOMAN IN THE SUN'
# 9                                 A Double-sided Study
# 10                                        Rich's House
# 11                                    Cape Ann Granite
# 12                  ILLUSTRATION FOR NICHOLAS NICKLEBY
# 13                                          Storefront
# 14                                     SPINDLY LOCUSTS
# 15                                  "Bridge on Seine,"
# 16                         "Temptation of St. Anthony"
# 17         "NYACK WITH STEEPLE OF SAINT ANNE'S CHURCH"
# 18                 FIGURE STUDY FOR "CAPE COD MORNING"
# 19                           The Artist's Sister, 1899
# 20                               Black and white scene
# 21                                      Standing Woman
# 22                                   CHURCH IN EASTHAM
# 23                              Study of a Night Shirt
# 24                              "Study for "The City""
# 25                "Scarboro Bridge & Lake, Mass [sic]"
# 26   Letter with a Sketch of an Artist at Work by a...
# 27                          South of Washington Square
# 28                                        Two Puritans
# 29                               House with Dead Trees
# ..                                                 ...
# 266                               Captain Uptons House
# 267               House on Cape Cod ( The White House)
# 268                                       Maine in Fog
# 269                                       Hotel Window
# 270                            Woman at Sewing Machine
# 271                                    Dauphinee House
# 272                                   Cape Ann Granite
# 273                                     Standing woman
# 274                      Study for Portrait of Orleans
# 275                                House in Gloucester
# 276                      Study for Portrait of Orleans
# 277                        Building with utility poles
# 278                                Drawing of nude man
# 279                         Study for 'Four Lane Road'
# 280                   Study for 'Office in small city'
# 281                    Study for 'Portrait of Orleans'
# 282                         Family home on Long Island
# 283                               Culvert at Orangburg
# 284                                      Head of woman
# 285                        Light Battery at Gettysburg
# 286                              Night on the El train
# 287                         Study for Les deux pigeons
# 288                                 Double-sided study
# 289                                   Seated gentleman
# 290                                  Tree in landscape
# 291                             Dead trees, Gloucester
# 292                            Study of woman knitting
# 293                                        Mount Moran
# 294                                     Rocks in Maine
# 295                                    Head of a woman
#
#                 Hammer_Price      Low_Estimate_price    High_Estimate_price  \
# 0                               <b>Low Estimate:</b>  <b>High Estimate:</b>
# 1                    $62,500                 $50,000                $70,000
# 2                $12,492,200             $12,000,000            $18,000,000
# 3                 $3,492,500              $2,000,000             $3,000,000
# 4                $91,875,000             $70,000,000           $100,000,000
# 5                     $5,860                  $5,000                 $7,000
# 6         $34,820  (€30,000)      $11,610  (€10,000)     $17,410  (€15,000)
# 7                   $225,000                $200,000               $300,000
# 8                   $150,000                $150,000               $250,000
# 9                     $4,613                  $3,500                 $5,500
# 10                $3,252,500              $2,000,000             $3,000,000
# 11                $8,412,500              $6,000,000             $8,000,000
# 12                    $5,630                  $5,000                 $7,000
# 13                   $15,000                  $4,000                 $6,000
# 14                -not sold-                $250,000               $350,000
# 15                    $7,560                  $3,000                 $5,000
# 16                -not sold-                 $12,000                $18,000
# 17                   $15,000                 $20,000                $30,000
# 18                   $35,000                  $8,000                $12,000
# 19                    $6,880                 $10,000                $15,000
# 20                    $5,500                  $1,000                 $1,500
# 21                -not sold-                 $20,000                $30,000
# 22                -not sold-                $600,000               $800,000
# 23                   $12,500                 $10,000                $15,000
# 24                   $45,600                 $20,000                $30,000
# 25                    $5,250                  $2,500                 $3,500
# 26                    $2,460                  $8,000                $12,000
# 27                  $437,000                $250,000               $350,000
# 28                -not sold-             $20,000,000            $30,000,000
# 29                -not sold-              $2,500,000             $3,500,000
# ..                       ...                     ...                    ...
# 266               $2,310,000              $1,200,000             $1,800,000
# 267                  $35,200                 $25,000                $35,000
# 268                  $52,250                 $30,000                $40,000
# 269               $1,320,000              $1,000,000             $1,500,000
# 270                  $29,700                 $15,000                $25,000
# 271                 $687,500                $500,000               $700,000
# 272                 $522,500                $200,000               $300,000
# 273                   $2,000                     n/a                    n/a
# 274                  $17,000                     n/a                    n/a
# 275                  $95,000                     n/a                    n/a
# 276                   $4,500                     n/a                    n/a
# 277                   $7,500                     n/a                    n/a
# 278                   $4,000                     n/a                    n/a
# 279                  $11,000                     n/a                    n/a
# 280                  $11,500                     n/a                    n/a
# 281                   $5,500                     n/a                    n/a
# 282                  $75,000                     n/a                    n/a
# 283                   $3,500                     n/a                    n/a
# 284                   $2,600                     n/a                    n/a
# 285                  $20,000                     n/a                    n/a
# 286                  $65,000                     n/a                    n/a
# 287                  $18,000                     n/a                    n/a
# 288                   $3,000                     n/a                    n/a
# 289                   $6,000                     n/a                    n/a
# 290                   $5,000                     n/a                    n/a
# 291                  $40,000                     n/a                    n/a
# 292                   $4,000                     n/a                    n/a
# 293                  $50,000                     n/a                    n/a
# 294                   $3,000                     n/a                    n/a
# 295                   $3,250                     n/a                    n/a
#
#                            Signature  \
# 0                        Unavailable
# 1                          Inscribed
# 2                  Signed Lower Left
# 3                 Signed Lower Right
# 4                 Signed Lower Right
# 5                  Signed and Titled
# 6                 Signed Lower Right
# 7                        Unavailable
# 8                        Unavailable
# 9                           Unsigned
# 10              Inscribed and Signed
# 11                Signed Lower Right
# 12                 Signed and Titled
# 13                       Unavailable
# 14                Signed Lower Right
# 15                Signed Lower Right
# 16                 Signed and Titled
# 17                       Unavailable
# 18                       Unavailable
# 19                  Signed and Dated
# 20                 Signed Lower Left
# 21                  Signed and Dated
# 22                Signed Lower Right
# 23                  Signed and Dated
# 24                       Unavailable
# 25                Signed Lower Right
# 26                            Signed
# 27                Signed Lower Right
# 28                 Signed Lower Left
# 29                Signed Lower Right
# ..                               ...
# 266                      Unavailable
# 267                      Unavailable
# 268                      Unavailable
# 269                      Unavailable
# 270                      Unavailable
# 271                      Unavailable
# 272                      Unavailable
# 273                 Signed and Dated
# 274                      Unavailable
# 275             Inscribed and Signed
# 276                      Unavailable
# 277                      Unavailable
# 278                           Signed
# 279                      Unavailable
# 280                      Unavailable
# 281                      Unavailable
# 282             Inscribed and Signed
# 283             Inscribed and Signed
# 284                 Signed and Dated
# 285                           Signed
# 286             Inscribed and Signed
# 287             Inscribed and Signed
# 288                      Unavailable
# 289                 Signed and Dated
# 290                           Signed
# 291                 Signed and Dated
# 292                      Unavailable
# 293                           Signed
# 294                           Signed
# 295                 Signed and Dated
#
#                                                   Size  \
# 0                                                <br/>
# 1                                   (27.94cm x 20.8...
# 2                                   (73.66cm x 101....
# 3                                   (50.80cm x 71.1...
# 4                                   (81.28cm x 96.5...
# 5                                   (21.59cm x 29.2...
# 6                                   (17.48cm x 12.7...
# 7                                   (19.69cm x 26.0...
# 8                                   (19.69cm x 26.0...
# 9                                   (46.99cm x 29.3...
# 10                                  (40.64cm x 63.5...
# 11                                  (73.66cm x 102....
# 12                                  (31.12cm x 23.8...
# 13                                  (13.97cm x 21.5...
# 14                                  (51.44cm x 65.4...
# 15                                  (41.91cm x 33.0...
# 16                                  (31.12cm x 22.8...
# 17                                  (19.20cm x 26.1...
# 18                                  (29.54cm x 21.9...
# 19                                  (42.55cm x 31.7...
# 20                                  (46.36cm x 32.3...
# 21                                  (57.15cm x 35.5...
# 22                                  (54.94cm x 67.6...
# 23                                  (17.15cm x 15.8...
# 24                                  (21.59cm x 27.9...
# 25                                  (20.32cm x 27.9...
# 26                                  (21.59cm x 27.9...
# 27                                  (36.83cm x 57.1...
# 28                                  (76.20cm x 101....
# 29                                  (50.80cm x 71.1...
# ..                                                 ...
# 266                                 (72.39cm x 92.0...
# 267                                 (35.56cm x 53.3...
# 268                                 (38.10cm x 55.8...
# 269                                 (101.60cm x 139...
# 270                                 (24.13cm x 21.5...
# 271                                 (86.36cm x 127....
# 272                                 (71.12cm x 101....
# 273                                 (55.88cm x 35.5...
# 274                                 (25.40cm x 40.6...
# 275                                 (33.02cm x 50.8...
# 276                                 (25.40cm x 40.6...
# 277                                 (25.40cm x 40.6...
# 278                                 (60.96cm x 38.1...
# 279                                 (27.94cm x 40.6...
# 280                                 (22.86cm x 27.9...
# 281                                 (22.86cm x 27.9...
# 282                                 (20.32cm x 33.0...
# 283                                 (25.40cm x 35.5...
# 284                                 (38.10cm x 27.9...
# 285                                 (43.18cm x 63.5...
# 286                                 (25.40cm x 27.9...
# 287                                 (27.94cm x 33.0...
# 288                                 (48.26cm x 27.9...
# 289                                 (27.94cm x 17.7...
# 290                                 (50.80cm x 35.5...
# 291                                 (33.02cm x 48.2...
# 292                                 (22.86cm x 20.3...
# 293                                 (53.34cm x 71.1...
# 294                                 (18.00cm x 21.0...
# 295                                 (39.00cm x 28.0...
#
#                  created_date                               Medium  \
# 0                        1938                   Watercolor / Paper
# 1                        1941  Pencil  and charcoal on cream paper
# 2                        1966                         Oil / Canvas
# 3                        1938        Watercolor and pencil / Paper
# 4                        1929                         Oil / Canvas
# 5                   not given                       Pencil / Paper
# 6                        1900                       Pencil / Paper
# 7                        1947                     Charcoal / Paper
# 8                        1961                     Charcoal / Paper
# 9                   not given                       Pencil / Paper
# 10                       1930     Watercolor  and charcoal / Paper
# 11                       1928                         Oil / Canvas
# 12                     c.1927                     Charcoal / Paper
# 13                  not given                     Charcoal / Paper
# 14                       1936        Watercolor and pencil / Paper
# 15                       1907                       Pencil / Paper
# 16                  c.1900-10                 Conte Crayon / Paper
# 17                     c.1905                        Pencil / Card
# 18                       1950                     Charcoal / Paper
# 19                       1899            Ink  and graphite / Paper
# 20                  not given                   Watercolor / Board
# 21                       1900              Ink  and pencil / Paper
# 22                       1948        Watercolor and pencil / Paper
# 23                       1901                       Pencil / Paper
# 24                  not given                     Charcoal / Paper
# 25                  not given                       Pencil / Paper
# 26                  not given                          Ink / Paper
# 27                     c.1915                Charcoal / Paperboard
# 28                       1945                         Oil / Canvas
# 29                       1932                   Watercolor / Paper
# ..                        ...                                  ...
# 266                 not given                         Oil / Canvas
# 267                 not given                             Charcoal
# 268                 not given                             Charcoal
# 269                 not given                         Oil / Canvas
# 270                 not given                               Crayon
# 271                 not given                         Oil / Canvas
# 272                 not given                         Oil / Canvas
# 273                      1899                       Pencil / Paper
# 274                 not given                             Charcoal
# 275                 not given                   Watercolor / Paper
# 276                 not given                             Charcoal
# 277                 not given                             Charcoal
# 278                 not given                             Charcoal
# 279                 not given                             Charcoal
# 280                 not given                             Charcoal
# 281                 not given                             Charcoal
# 282                 not given                   Watercolor / Paper
# 283                      1900                             Charcoal
# 284                      1899                             Charcoal
# 285                 not given                             Charcoal
# 286                 not given                             Charcoal
# 287                 not given                             Charcoal
# 288                 not given                       Pencil / Paper
# 289                      1901                      Gouache / Board
# 290                 not given                   Watercolor / Paper
# 291                      1923                   Watercolor / Paper
# 292                 not given                       Pencil / Paper
# 293                 not given        Watercolor and pencil / Paper
# 294                 not given                       Pencil / Paper
# 295                      1899                             Charcoal
#
#             Auction_Lot                            Auction_House  \
# 0    Watercolor / Paper
# 1                    16                       Sotheby's New York
# 2                    15                       Sotheby's New York
# 3                   11B  Christie's New York, Rockefeller Center
# 4                   12B  Christie's New York, Rockefeller Center
# 5                    66                      Barridoff Galleries
# 6                   106                                Grisebach
# 7                    10                       Sotheby's New York
# 8                    12                       Sotheby's New York
# 9                   337                      Skinner Inc, Boston
# 10                  402  Christie's New York, Rockefeller Center
# 11                  408  Christie's New York, Rockefeller Center
# 12                   56                       Sotheby's New York
# 13                   44             Rago Arts and Auction Center
# 14                   49                       Sotheby's New York
# 15                 6167                    Clars Auction Gallery
# 16                   68                     Neal Auction Company
# 17                  140              04/06/2017
#
# 18                   34              10/20/2016
#
# 19                  226               Leslie Hindman Auctioneers
# 20                 4237                        Kaminski Auctions
# 21                    5                         Bonhams New York
# 22                   46                       Sotheby's New York
# 23                  120  Christie's New York, Rockefeller Center
# 24                   61              10/16/2015
#
# 25                  104                      Barridoff Galleries
# 26                  399                      Skinner Inc, Boston
# 27                    7  Christie's New York, Rockefeller Center
# 28                   10  Christie's New York, Rockefeller Center
# 29                   11  Christie's New York, Rockefeller Center
# ..                  ...                                      ...
# 266                 304                       Sotheby's New York
# 267                 305                       Sotheby's New York
# 268                 306                       Sotheby's New York
# 269                 315                       Sotheby's New York
# 270                 318                       Sotheby's New York
# 271                 331                       Sotheby's New York
# 272                 335                       Sotheby's New York
# 273                 179                       Sotheby's New York
# 274                 233              05/29/1986
#
# 275                 234                       Sotheby's New York
# 276                 242              12/05/1985
#
# 277                 243              12/05/1985
#
# 278                  46                 Skinner Inc, Marlborough
# 279               220 a              05/30/1985
#
# 280               220 b              05/30/1985
#
# 281               220 c              05/30/1985
#
# 282                  70                      Barridoff Galleries
# 283                 259  Christie's New York, Rockefeller Center
# 284                 304                       Sotheby's New York
# 285                 191                       Sotheby's New York
# 286                 268  Christie's New York, Rockefeller Center
# 287                 271  Christie's New York, Rockefeller Center
# 288               275 a  Christie's New York, Rockefeller Center
# 289               275 b  Christie's New York, Rockefeller Center
# 290                1361      Weschler's Auctioneers & Appraisers
# 291                 211                       Sotheby's New York
# 292                  38  Christie's New York, Rockefeller Center
# 293                 149                       Sotheby's New York
# 294                 106  Christie's New York, Rockefeller Center
# 295                 149                       Sotheby's New York
#
#                                     Auction_Date
# 0                                           None
# 1                    03/06/2019
#
# 2                    11/16/2018
#
# 3                    11/13/2018
#
# 4                    11/13/2018
#
# 5                    10/27/2018
#
# 6                    10/25/2018
#
# 7                    05/23/2018
#
# 8                    05/23/2018
#
# 9                    05/11/2018
#
# 10                   05/09/2018
#
# 11                   05/09/2018
#
# 12                   03/28/2018
#
# 13                   11/11/2017
#
# 14                   05/23/2017
#
# 15                   05/21/2017
#
# 16        04/22/2017-04/23/2017
#
# 17                 See all lots for this auction
# 18                 See all lots for this auction
# 19                   09/29/2016
#
# 20                   09/11/2016
#
# 21                   05/18/2016
#
# 22                   05/18/2016
#
# 23                   11/19/2015
#
# 24                 See all lots for this auction
# 25                   10/16/2015
#
# 26                   09/11/2015
#
# 27                   05/21/2015
#
# 28                   05/21/2015
#
# 29                   05/21/2015
#
# ..                                           ...
# 266                  12/03/1987
#
# 267                  12/03/1987
#
# 268                  12/03/1987
#
# 269                  12/03/1987
#
# 270                  12/03/1987
#
# 271                  12/03/1987
#
# 272                  12/03/1987
#
# 273                  10/24/1986
#
# 274                See all lots for this auction
# 275                  05/29/1986
#
# 276                See all lots for this auction
# 277                See all lots for this auction
# 278                  11/26/1985
#
# 279                See all lots for this auction
# 280                See all lots for this auction
# 281                See all lots for this auction
# 282                  05/11/1985
#
# 283                  03/15/1985
#
# 284                  06/22/1984
#
# 285                  05/31/1984
#
# 286                  12/09/1983
#
# 287                  12/09/1983
#
# 288                  12/09/1983
#
# 289                  12/09/1983
#
# 290                  10/02/1983
#
# 291                  06/02/1983
#
# 292                  03/18/1983
#
# 293                  06/04/1982
#
# 294                  04/07/1982
#
# 295                  03/11/1982
#
#
# [296 rows x 11 columns]

# %% [markdown]
# # Cleaning process for null, incomplete and inregular value

# %%
df=df.fillna("0")

# %%
houselist=[]

# %%
driver.find_element_by_xpath('//div[@class="pagination BiggerPaginator"]//a[@class="first"]').click()

# %%
x=0
while x < 12:
    try:
            soup_level1=BeautifulSoup(driver.page_source, 'lxml')
            for link in soup_level1.find_all('div',attrs={"class":"PriceBox"}):
                if link.contents[38].string != None:  
                    houselist.append(link.contents[38].string)
          
            driver.find_element_by_xpath('//div[@class="pagination BiggerPaginator"]//a[@class="next"]').click()
            x+=1  
    except:
            break
            print("The scraping has came to an end")

# %%
df["High_Estimate_price"]=df["High_Estimate_price"].replace('\(([^()]|())*\)', '',regex=True)
df["Low_Estimate_price"]=df["Low_Estimate_price"].replace('\(([^()]|())*\)', '',regex=True)
df["Title"]=df["Title"].replace('\(([^()]|())*\)', '',regex=True)
df["Hammer_Price"]=df["Hammer_Price"].replace('\(([^()]|())*\)', '',regex=True)

# %%
df["Low_Estimate_price"]=df["Low_Estimate_price"].str.replace('$', '')
df["Low_Estimate_price"]=df["Low_Estimate_price"].str.replace(',', '')
df["Low_Estimate_price"]=df["Low_Estimate_price"].str.replace('n/a', '0')
df["Low_Estimate_price"]=df["Low_Estimate_price"].str.replace('\xa0', '')

# %%
df["High_Estimate_price"]=df["High_Estimate_price"].str.replace('$', '')
df["High_Estimate_price"]=df["High_Estimate_price"].str.replace(',', '')
df["High_Estimate_price"]=df["High_Estimate_price"].str.replace('n/a', '0')
df["High_Estimate_price"]=df["High_Estimate_price"].str.replace('\xa0', '')

# %%
df["created_date"]=df["created_date"].str.replace('c.', '')
df["created_date"]=df["created_date"].str.replace('. ', '')
df["created_date"]=df["created_date"].str.replace('.', '')
df["Auction_House"]=df["Auction_House"].str.replace('\xa0', '')

# %%
df["Hammer_Price"]=df["Hammer_Price"].str.replace('$', '')
df["Hammer_Price"]=df["Hammer_Price"].str.replace(',', '')

# %%
df=df.drop([0])

# %%
for i in df.index:
    if df["Auction_House"][i] is not np.nan: 
        if df["Auction_House"][i][-1]==' ':
            df["Auction_Date"][i]=df["Auction_House"][i]

# %%
for i in df.index:
      for e in range(len(houselist)):
        if df["Auction_House"][i] !='':
            if df["Auction_House"][i][-1]==' ':
                    df["Auction_House"][i]=houselist[e]

# %%
import collections

# %%
collections.Counter(df["Auction_House"])
# Out:
# Counter({'Aspire Auctions, Cleveland': 1,
#          'Barridoff Galleries': 7,
#          'Bonhams California': 2,
#          'Bonhams New York': 2,
#          'CRN Auctions': 1,
#          'Christie\'s New York, "East"': 8,
#          "Christie's New York, Rockefeller Center": 83,
#          'Clars Auction Gallery': 1,
#          'David Rago': 3,
#          'Doyle New York': 2,
#          'DuMouchelles Auction House': 1,
#          'Frank H Boos Gallery': 1,
#          "Freeman's": 22,
#          'Grisebach': 1,
#          'Heritage Auctions': 5,
#          'James D Julia, Inc.': 1,
#          'Kaminski Auctions': 1,
#          'Leslie Hindman Auctioneers': 2,
#          'Louisiana Auction Exchange Inc': 5,
#          'Mastro Auctions (see Legendary Auctions)': 2,
#          "Michaan's Auctions": 1,
#          'Midwest Auction Galleries': 2,
#          'Neal Auction Company': 3,
#          'New Orleans Auction Galleries Inc': 1,
#          'Pook & Pook Inc.': 6,
#          'Provincetown Art Association Benefit Auction': 1,
#          'Rago Arts and Auction Center': 18,
#          'Scottsdale Art Auction': 2,
#          "Shannon's Fine Art Auctioneers": 1,
#          'Skinner Inc, Boston': 2,
#          'Skinner Inc, Marlborough': 1,
#          "Sotheby's London, New Bond Street": 1,
#          "Sotheby's New York": 88,
#          "Sotheby's New York, Arcade": 5,
#          'Swann Galleries': 4,
#          'Vallot Fine Art Auctioneers': 6,
#          "Weschler's Auctioneers & Appraisers": 2})

# %%
sold_status=[]

# %%
for i in df.index:
    if df["Hammer_Price"][i]=="-not sold-":
        sold_status.append("not sold")
    else:
        sold_status.append("sold")

# %%
df["sold_status"]=sold_status

# %%
for i in df.index:
     if df["Hammer_Price"][i] =='not communicated':
            df=df.drop([i])

# %%
df["Hammer_Price"]=df["Hammer_Price"].str.replace('-not sold-', '0')

# %%
df["Hammer_Price"]=df["Hammer_Price"].str.replace('\xa0', '')
df["created_date"]=df["created_date"].str.replace('\xa0', '')
df["Medium"]=df["Medium"].str.replace('\xa0', '')

# %%
df["Size"]=df["Size"].str.replace(')', '')

# %%
df["Size"]=df["Size"].str.replace('(', '')
df["Size"]=df["Size"].str.replace('cm', '')
df["Size"]=df["Size"].str.replace('\xa0', '')

# %%
df=df.fillna("0")
# Out:
#                                                  Title Hammer_Price  \
# 1                              STUDY FOR 'GIRLIE SHOW'        62500
# 2                                        TWO COMEDIANS     12492200
# 3                              Cottages at North Truro      3492500
# 4                                            Chop Suey     91875000
# 5                             "Scarboro Bridge & Lake"         5860
# 6                                      "STUDY OF FEET"        34820
# 7                           STUDY FOR 'SUMMER EVENING'       225000
# 8                       STUDY FOR 'A WOMAN IN THE SUN'       150000
# 9                                 A Double-sided Study         4613
# 10                                        Rich's House      3252500
# 11                                    Cape Ann Granite      8412500
# 12                  ILLUSTRATION FOR NICHOLAS NICKLEBY         5630
# 13                                          Storefront        15000
# 14                                     SPINDLY LOCUSTS            0
# 15                                  "Bridge on Seine,"         7560
# 16                         "Temptation of St. Anthony"            0
# 17         "NYACK WITH STEEPLE OF SAINT ANNE'S CHURCH"        15000
# 18                 FIGURE STUDY FOR "CAPE COD MORNING"        35000
# 19                           The Artist's Sister, 1899         6880
# 20                               Black and white scene         5500
# 21                                      Standing Woman            0
# 22                                   CHURCH IN EASTHAM            0
# 23                              Study of a Night Shirt        12500
# 24                              "Study for "The City""        45600
# 25                "Scarboro Bridge & Lake, Mass [sic]"         5250
# 26   Letter with a Sketch of an Artist at Work by a...         2460
# 27                          South of Washington Square       437000
# 28                                        Two Puritans            0
# 29                               House with Dead Trees            0
# 30                          Study for Cape Cod Morning        45000
# ..                                                 ...          ...
# 266                               Captain Uptons House      2310000
# 267                                 House on Cape Cod         35200
# 268                                       Maine in Fog        52250
# 269                                       Hotel Window      1320000
# 270                            Woman at Sewing Machine        29700
# 271                                    Dauphinee House       687500
# 272                                   Cape Ann Granite       522500
# 273                                     Standing woman         2000
# 274                      Study for Portrait of Orleans        17000
# 275                                House in Gloucester        95000
# 276                      Study for Portrait of Orleans         4500
# 277                        Building with utility poles         7500
# 278                                Drawing of nude man         4000
# 279                         Study for 'Four Lane Road'        11000
# 280                   Study for 'Office in small city'        11500
# 281                    Study for 'Portrait of Orleans'         5500
# 282                         Family home on Long Island        75000
# 283                               Culvert at Orangburg         3500
# 284                                      Head of woman         2600
# 285                        Light Battery at Gettysburg        20000
# 286                              Night on the El train        65000
# 287                         Study for Les deux pigeons        18000
# 288                                 Double-sided study         3000
# 289                                   Seated gentleman         6000
# 290                                  Tree in landscape         5000
# 291                             Dead trees, Gloucester        40000
# 292                            Study of woman knitting         4000
# 293                                        Mount Moran        50000
# 294                                     Rocks in Maine         3000
# 295                                    Head of a woman         3250
#
#     Low_Estimate_price High_Estimate_price                        Signature  \
# 1                50000               70000                        Inscribed
# 2             12000000            18000000                Signed Lower Left
# 3              2000000             3000000               Signed Lower Right
# 4             70000000           100000000               Signed Lower Right
# 5                 5000                7000                Signed and Titled
# 6                11610               17410               Signed Lower Right
# 7               200000              300000                      Unavailable
# 8               150000              250000                      Unavailable
# 9                 3500                5500                         Unsigned
# 10             2000000             3000000             Inscribed and Signed
# 11             6000000             8000000               Signed Lower Right
# 12                5000                7000                Signed and Titled
# 13                4000                6000                      Unavailable
# 14              250000              350000               Signed Lower Right
# 15                3000                5000               Signed Lower Right
# 16               12000               18000                Signed and Titled
# 17               20000               30000                      Unavailable
# 18                8000               12000                      Unavailable
# 19               10000               15000                 Signed and Dated
# 20                1000                1500                Signed Lower Left
# 21               20000               30000                 Signed and Dated
# 22              600000              800000               Signed Lower Right
# 23               10000               15000                 Signed and Dated
# 24               20000               30000                      Unavailable
# 25                2500                3500               Signed Lower Right
# 26                8000               12000                           Signed
# 27              250000              350000               Signed Lower Right
# 28            20000000            30000000                Signed Lower Left
# 29             2500000             3500000               Signed Lower Right
# 30               40000               60000                      Unavailable
# ..                 ...                 ...                              ...
# 266            1200000             1800000                      Unavailable
# 267              25000               35000                      Unavailable
# 268              30000               40000                      Unavailable
# 269            1000000             1500000                      Unavailable
# 270              15000               25000                      Unavailable
# 271             500000              700000                      Unavailable
# 272             200000              300000                      Unavailable
# 273                  0                   0                 Signed and Dated
# 274                  0                   0                      Unavailable
# 275                  0                   0             Inscribed and Signed
# 276                  0                   0                      Unavailable
# 277                  0                   0                      Unavailable
# 278                  0                   0                           Signed
# 279                  0                   0                      Unavailable
# 280                  0                   0                      Unavailable
# 281                  0                   0                      Unavailable
# 282                  0                   0             Inscribed and Signed
# 283                  0                   0             Inscribed and Signed
# 284                  0                   0                 Signed and Dated
# 285                  0                   0                           Signed
# 286                  0                   0             Inscribed and Signed
# 287                  0                   0             Inscribed and Signed
# 288                  0                   0                      Unavailable
# 289                  0                   0                 Signed and Dated
# 290                  0                   0                           Signed
# 291                  0                   0                 Signed and Dated
# 292                  0                   0                      Unavailable
# 293                  0                   0                           Signed
# 294                  0                   0                           Signed
# 295                  0                   0                 Signed and Dated
#
#                                                   Size created_date  \
# 1                                    27.94cm x 20.83cm         1941
# 2                                   73.66cm x 101.60cm         1966
# 3                                    50.80cm x 71.12cm         1938
# 4                                    81.28cm x 96.52cm         1929
# 5                                    21.59cm x 29.21cm      nogiven
# 6                                    17.48cm x 12.70cm         1900
# 7                                    19.69cm x 26.04cm         1947
# 8                                    19.69cm x 26.04cm         1961
# 9                                    46.99cm x 29.36cm      nogiven
# 10                                   40.64cm x 63.50cm         1930
# 11                                  73.66cm x 102.24cm         1928
# 12                                   31.12cm x 23.83cm         1927
# 13                                   13.97cm x 21.59cm      nogiven
# 14                                   51.44cm x 65.41cm         1936
# 15                                   41.91cm x 33.02cm         1907
# 16                                   31.12cm x 22.86cm      1900-10
# 17                                   19.20cm x 26.10cm         1905
# 18                                   29.54cm x 21.92cm         1950
# 19                                   42.55cm x 31.75cm         1899
# 20                                   46.36cm x 32.39cm      nogiven
# 21                                   57.15cm x 35.56cm         1900
# 22                                   54.94cm x 67.64cm         1948
# 23                                   17.15cm x 15.88cm         1901
# 24                                   21.59cm x 27.94cm      nogiven
# 25                                   20.32cm x 27.94cm      nogiven
# 26                                   21.59cm x 27.94cm      nogiven
# 27                                   36.83cm x 57.15cm         1915
# 28                                  76.20cm x 101.60cm         1945
# 29                                   50.80cm x 71.12cm         1932
# 30                                   20.32cm x 26.37cm      nogiven
# ..                                                 ...          ...
# 266                                  72.39cm x 92.08cm      nogiven
# 267                                  35.56cm x 53.34cm      nogiven
# 268                                  38.10cm x 55.88cm      nogiven
# 269                                 101.60cm x 139....      nogiven
# 270                                  24.13cm x 21.59cm      nogiven
# 271                                 86.36cm x 127.64cm      nogiven
# 272                                 71.12cm x 101.60cm      nogiven
# 273                                  55.88cm x 35.56cm         1899
# 274                                  25.40cm x 40.64cm      nogiven
# 275                                  33.02cm x 50.80cm      nogiven
# 276                                  25.40cm x 40.64cm      nogiven
# 277                                  25.40cm x 40.64cm      nogiven
# 278                                  60.96cm x 38.10cm      nogiven
# 279                                  27.94cm x 40.64cm      nogiven
# 280                                  22.86cm x 27.94cm      nogiven
# 281                                  22.86cm x 27.94cm      nogiven
# 282                                  20.32cm x 33.02cm      nogiven
# 283                                  25.40cm x 35.56cm         1900
# 284                                  38.10cm x 27.94cm         1899
# 285                                  43.18cm x 63.50cm      nogiven
# 286                                  25.40cm x 27.94cm      nogiven
# 287                                  27.94cm x 33.02cm      nogiven
# 288                                  48.26cm x 27.94cm      nogiven
# 289                                  27.94cm x 17.78cm         1901
# 290                                  50.80cm x 35.56cm      nogiven
# 291                                  33.02cm x 48.26cm         1923
# 292                                  22.86cm x 20.32cm      nogiven
# 293                                  53.34cm x 71.12cm      nogiven
# 294                                  18.00cm x 21.00cm      nogiven
# 295                                  39.00cm x 28.00cm         1899
#
#                                   Medium    Auction_Lot  \
# 1    Pencil  and charcoal on cream paper             16
# 2                           Oil / Canvas             15
# 3          Watercolor and pencil / Paper            11B
# 4                           Oil / Canvas            12B
# 5                         Pencil / Paper             66
# 6                         Pencil / Paper            106
# 7                       Charcoal / Paper             10
# 8                       Charcoal / Paper             12
# 9                         Pencil / Paper            337
# 10      Watercolor  and charcoal / Paper            402
# 11                          Oil / Canvas            408
# 12                      Charcoal / Paper             56
# 13                      Charcoal / Paper             44
# 14         Watercolor and pencil / Paper             49
# 15                        Pencil / Paper           6167
# 16                  Conte Crayon / Paper             68
# 17                         Pencil / Card            140
# 18                      Charcoal / Paper             34
# 19             Ink  and graphite / Paper            226
# 20                    Watercolor / Board           4237
# 21               Ink  and pencil / Paper              5
# 22         Watercolor and pencil / Paper             46
# 23                        Pencil / Paper            120
# 24                      Charcoal / Paper             61
# 25                        Pencil / Paper            104
# 26                           Ink / Paper            399
# 27                 Charcoal / Paperboard              7
# 28                          Oil / Canvas             10
# 29                    Watercolor / Paper             11
# 30                  Conte Crayon / Paper             62
# ..                                   ...            ...
# 266                         Oil / Canvas            304
# 267                             Charcoal            305
# 268                             Charcoal            306
# 269                         Oil / Canvas            315
# 270                               Crayon            318
# 271                         Oil / Canvas            331
# 272                         Oil / Canvas            335
# 273                       Pencil / Paper            179
# 274                             Charcoal            233
# 275                   Watercolor / Paper            234
# 276                             Charcoal            242
# 277                             Charcoal            243
# 278                             Charcoal             46
# 279                             Charcoal          220 a
# 280                             Charcoal          220 b
# 281                             Charcoal          220 c
# 282                   Watercolor / Paper             70
# 283                             Charcoal            259
# 284                             Charcoal            304
# 285                             Charcoal            191
# 286                             Charcoal            268
# 287                             Charcoal            271
# 288                       Pencil / Paper          275 a
# 289                      Gouache / Board          275 b
# 290                   Watercolor / Paper           1361
# 291                   Watercolor / Paper            211
# 292                       Pencil / Paper             38
# 293        Watercolor and pencil / Paper            149
# 294                       Pencil / Paper            106
# 295                             Charcoal            149
#
#                                Auction_House  \
# 1                         Sotheby's New York
# 2                         Sotheby's New York
# 3    Christie's New York, Rockefeller Center
# 4    Christie's New York, Rockefeller Center
# 5                        Barridoff Galleries
# 6                                  Grisebach
# 7                         Sotheby's New York
# 8                         Sotheby's New York
# 9                        Skinner Inc, Boston
# 10   Christie's New York, Rockefeller Center
# 11   Christie's New York, Rockefeller Center
# 12                        Sotheby's New York
# 13              Rago Arts and Auction Center
# 14                        Sotheby's New York
# 15                     Clars Auction Gallery
# 16                      Neal Auction Company
# 17                                 Freeman's
# 18                                 Freeman's
# 19                Leslie Hindman Auctioneers
# 20                         Kaminski Auctions
# 21                          Bonhams New York
# 22                        Sotheby's New York
# 23   Christie's New York, Rockefeller Center
# 24                                 Freeman's
# 25                       Barridoff Galleries
# 26                       Skinner Inc, Boston
# 27   Christie's New York, Rockefeller Center
# 28   Christie's New York, Rockefeller Center
# 29   Christie's New York, Rockefeller Center
# 30                                 Freeman's
# ..                                       ...
# 266                       Sotheby's New York
# 267                       Sotheby's New York
# 268                       Sotheby's New York
# 269                       Sotheby's New York
# 270                       Sotheby's New York
# 271                       Sotheby's New York
# 272                       Sotheby's New York
# 273                       Sotheby's New York
# 274                                Freeman's
# 275                       Sotheby's New York
# 276                                Freeman's
# 277                                Freeman's
# 278                 Skinner Inc, Marlborough
# 279                                Freeman's
# 280                                Freeman's
# 281                                Freeman's
# 282                      Barridoff Galleries
# 283  Christie's New York, Rockefeller Center
# 284                       Sotheby's New York
# 285                       Sotheby's New York
# 286  Christie's New York, Rockefeller Center
# 287  Christie's New York, Rockefeller Center
# 288  Christie's New York, Rockefeller Center
# 289  Christie's New York, Rockefeller Center
# 290      Weschler's Auctioneers & Appraisers
# 291                       Sotheby's New York
# 292  Christie's New York, Rockefeller Center
# 293                       Sotheby's New York
# 294  Christie's New York, Rockefeller Center
# 295                       Sotheby's New York
#
#                                     Auction_Date sold_status
# 1                    03/06/2019
#                         sold
# 2                    11/16/2018
#                         sold
# 3                    11/13/2018
#                         sold
# 4                    11/13/2018
#                         sold
# 5                    10/27/2018
#                         sold
# 6                    10/25/2018
#                         sold
# 7                    05/23/2018
#                         sold
# 8                    05/23/2018
#                         sold
# 9                    05/11/2018
#                         sold
# 10                   05/09/2018
#                         sold
# 11                   05/09/2018
#                         sold
# 12                   03/28/2018
#                         sold
# 13                   11/11/2017
#                         sold
# 14                   05/23/2017
#                         sold
# 15                   05/21/2017
#                         sold
# 16        04/22/2017-04/23/2017
#                         sold
# 17                  04/06/2017\n                        sold
# 18                  10/20/2016\n                        sold
# 19                   09/29/2016
#                         sold
# 20                   09/11/2016
#                         sold
# 21                   05/18/2016
#                         sold
# 22                   05/18/2016
#                         sold
# 23                   11/19/2015
#                         sold
# 24                  10/16/2015\n                        sold
# 25                   10/16/2015
#                         sold
# 26                   09/11/2015
#                         sold
# 27                   05/21/2015
#                         sold
# 28                   05/21/2015
#                         sold
# 29                   05/21/2015
#                         sold
# 30                  04/29/2015\n                        sold
# ..                                           ...         ...
# 266                  12/03/1987
#                         sold
# 267                  12/03/1987
#                         sold
# 268                  12/03/1987
#                         sold
# 269                  12/03/1987
#                         sold
# 270                  12/03/1987
#                         sold
# 271                  12/03/1987
#                         sold
# 272                  12/03/1987
#                         sold
# 273                  10/24/1986
#                         sold
# 274                 05/29/1986\n                        sold
# 275                  05/29/1986
#                         sold
# 276                 12/05/1985\n                        sold
# 277                 12/05/1985\n                        sold
# 278                  11/26/1985
#                         sold
# 279                 05/30/1985\n                        sold
# 280                 05/30/1985\n                        sold
# 281                 05/30/1985\n                        sold
# 282                  05/11/1985
#                         sold
# 283                  03/15/1985
#                         sold
# 284                  06/22/1984
#                         sold
# 285                  05/31/1984
#                         sold
# 286                  12/09/1983
#                         sold
# 287                  12/09/1983
#                         sold
# 288                  12/09/1983
#                         sold
# 289                  12/09/1983
#                         sold
# 290                  10/02/1983
#                         sold
# 291                  06/02/1983
#                         sold
# 292                  03/18/1983
#                         sold
# 293                  06/04/1982
#                         sold
# 294                  04/07/1982
#                         sold
# 295                  03/11/1982
#                         sold
#
# [295 rows x 12 columns]

# %%
for i in df.index:
    if df["Medium"][i]== None:
        df=df.drop([i])

# %%
import numpy as np
for i in df.index:
    if df["Size"][i] is np.nan:
        df=df.drop[i]

# %%
Width=[]
Height=[]

# %%
for i in df["Size"].str.split("x"):
        Width.append(i[0])
        Height.append(i[1])

# %%
df["height"]=Height
df["width"]=Width
df["width"]=df["width"].astype(float)
df["height"]=df["height"].astype(float)

# %%
df["Signature"]=df["Signature"].str.replace("\xa0","")
df["Auction_Date"]=df["Auction_Date"].str.replace("\xa0","")
df["Auction_Lot"]=df["Auction_Lot"].str.replace("\xa0","")

# %%
df=df.drop(["Size"],axis=1)

# %%
df.to_csv("hopper_auc.csv", index=False,encoding="utf-8")

# %%
#import pandas as pd # or just open the csv saved
#X=pd.read_csv("auction_csv/hopper_auc.csv")

# %%
import copy
X=copy.deepcopy(df)

# %%
Y=X["Hammer_Price"]

# %%
def get_transform(data,col):
    le = preprocessing.LabelEncoder()
    le.fit(data[col])
    data[col]=le.transform(data[col])

# %%
for i in X.index:
    if X["Medium"][i]== None:
        X.drop([i])

# %%
for i in X.index:
    if X["Size"][i] is np.nan:
        X=X.drop[i]

# %%
for i in X.index:
     if X["Hammer_Price"][i] =='not communicated':
            X=X.drop([i])

# %%
get_transform(X,"Signature")
get_transform(X,"Medium")
get_transform(X,"Auction_House")
get_transform(X,"Auction_Date")
get_transform(X,"sold_status")
get_transform(X,"Title")
get_transform(X,"created_date")

# %%
X["Auction_Lot"]=X["Auction_Lot"].str.replace("A","")
X["Auction_Lot"]=X["Auction_Lot"].str.replace("a","")
X["Auction_Lot"]=X["Auction_Lot"].str.replace("b","")
X["Auction_Lot"]=X["Auction_Lot"].str.replace("B","")
X["Auction_Lot"]=X["Auction_Lot"].str.replace("E","")
X["Auction_Lot"]=X["Auction_Lot"].str.replace("D","")
X["Auction_Lot"]=X["Auction_Lot"].str.replace("C","")
X["Auction_Lot"]=X["Auction_Lot"].str.replace(" c","")
X["Auction_Lot"]=X["Auction_Lot"].str.replace("\xa0","")

# %%
X["Auction_Lot"]=X["Auction_Lot"].astype(int)

# %%
X["Low_Estimate_price"]=X["Low_Estimate_price"].astype(int)

# %%
X["Hammer_Price"]=X["Hammer_Price"].astype(int)

# %%
X["High_Estimate_price"]=X["High_Estimate_price"].astype(int)

# %%
X.corr()
# Out:
#                         Title  Hammer_Price  Low_Estimate_price  \
# Title                1.000000     -0.121785           -0.076920
# Hammer_Price        -0.121785      1.000000            0.943878
# Low_Estimate_price  -0.076920      0.943878            1.000000
# High_Estimate_price -0.073490      0.937295            0.999282
# Signature           -0.018238     -0.020776           -0.020908
# created_date         0.042679     -0.052145           -0.054615
# Medium              -0.112018      0.060061            0.063990
# Auction_Lot         -0.107534     -0.021432           -0.021755
# Auction_House       -0.000636     -0.082842           -0.090105
# Auction_Date         0.074612      0.070182            0.059982
# sold_status               NaN           NaN                 NaN
# height              -0.122137      0.418283            0.392998
# width               -0.128250      0.390745            0.366860
#
#                      High_Estimate_price  Signature  created_date    Medium  \
# Title                          -0.073490  -0.018238      0.042679 -0.112018
# Hammer_Price                    0.937295  -0.020776     -0.052145  0.060061
# Low_Estimate_price              0.999282  -0.020908     -0.054615  0.063990
# High_Estimate_price             1.000000  -0.020626     -0.052627  0.064387
# Signature                      -0.020626   1.000000      0.219972 -0.238361
# created_date                   -0.052627   0.219972      1.000000 -0.211145
# Medium                          0.064387  -0.238361     -0.211145  1.000000
# Auction_Lot                    -0.021812   0.004747     -0.029767 -0.013284
# Auction_House                  -0.088932   0.007530      0.013741  0.057587
# Auction_Date                    0.059497  -0.109558     -0.030089  0.044819
# sold_status                          NaN        NaN           NaN       NaN
# height                          0.389300  -0.176582      0.031811  0.245297
# width                           0.364570  -0.185094     -0.068399  0.203830
#
#                      Auction_Lot  Auction_House  Auction_Date  sold_status  \
# Title                  -0.107534      -0.000636      0.074612          NaN
# Hammer_Price           -0.021432      -0.082842      0.070182          NaN
# Low_Estimate_price     -0.021755      -0.090105      0.059982          NaN
# High_Estimate_price    -0.021812      -0.088932      0.059497          NaN
# Signature               0.004747       0.007530     -0.109558          NaN
# created_date           -0.029767       0.013741     -0.030089          NaN
# Medium                 -0.013284       0.057587      0.044819          NaN
# Auction_Lot             1.000000      -0.053266     -0.006243          NaN
# Auction_House          -0.053266       1.000000     -0.033126          NaN
# Auction_Date           -0.006243      -0.033126      1.000000          NaN
# sold_status                  NaN            NaN           NaN          NaN
# height                 -0.055948       0.063823      0.189024          NaN
# width                  -0.016242       0.073419      0.144841          NaN
#
#                        height     width
# Title               -0.122137 -0.128250
# Hammer_Price         0.418283  0.390745
# Low_Estimate_price   0.392998  0.366860
# High_Estimate_price  0.389300  0.364570
# Signature           -0.176582 -0.185094
# created_date         0.031811 -0.068399
# Medium               0.245297  0.203830
# Auction_Lot         -0.055948 -0.016242
# Auction_House        0.063823  0.073419
# Auction_Date         0.189024  0.144841
# sold_status               NaN       NaN
# height               1.000000  0.847812
# width                0.847812  1.000000

# %%
import pandas as pd
import plotly as plt
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.graph_objs import *
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
py.sign_in("ruby1121","qaZHiBpKArxb0Mt5yLcQ")
plt.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data = [go.Heatmap( z=X.corr().values.tolist(),
                  x=['Title', 'Hammer_Price', 'Low_Estimate_price', 'High_Estimate_price',
       'Signature', 'created_date', 'Medium', 'Auction_Lot', 'Auction_House',
       'Auction_Date', 'width', 'height'],
                   y=['Title', 'Hammer_Price', 'Low_Estimate_price', 'High_Estimate_price',
       'Signature', 'created_date', 'Medium', 'Auction_Lot', 'Auction_House',
       'Auction_Date', 'width', 'height'])]

iplot(data, filename='labelled-heatmap2')
# Out:
# <div>
#
#
#             <div id="27ad0ed3-e247-403c-99fa-2de594839415" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("27ad0ed3-e247-403c-99fa-2de594839415")) {
#                     Plotly.newPlot(
#                         '27ad0ed3-e247-403c-99fa-2de594839415',
#                         [{"type": "heatmap", "uid": "19ed12e9-196e-4855-b063-4bc35f08e3d4", "x": ["Title", "Hammer_Price", "Low_Estimate_price", "High_Estimate_price", "Signature", "created_date", "Medium", "Auction_Lot", "Auction_House", "Auction_Date", "width", "height"], "y": ["Title", "Hammer_Price", "Low_Estimate_price", "High_Estimate_price", "Signature", "created_date", "Medium", "Auction_Lot", "Auction_House", "Auction_Date", "width", "height"], "z": [[1.0, -0.12178458957820532, -0.07692005272134424, -0.07348956632526547, -0.01823772318566655, 0.042679031654607055, -0.11201795434313827, -0.10753388444435509, -0.0006362831919527673, 0.07461164078418801, null, -0.12213711472985694, -0.1282498884315512], [-0.12178458957820532, 1.0, 0.943878341164728, 0.9372946927757487, -0.020776066984866826, -0.052144978191701497, 0.06006146384146293, -0.021431968683280594, -0.08284166161729371, 0.07018162145034698, null, 0.4182830849260688, 0.3907448692170001], [-0.07692005272134424, 0.943878341164728, 1.0, 0.9992820388321593, -0.020908054927296353, -0.054615051748212066, 0.0639904536477944, -0.021755150282697804, -0.09010514637742674, 0.05998191570492083, null, 0.392998163266371, 0.36686044934091194], [-0.07348956632526547, 0.9372946927757487, 0.9992820388321593, 1.0, -0.02062620336084502, -0.05262654232535161, 0.06438668437139708, -0.021812437984530315, -0.0889315774941549, 0.05949697567659089, null, 0.3892995109632348, 0.3645704478386024], [-0.01823772318566655, -0.020776066984866826, -0.020908054927296353, -0.02062620336084502, 1.0, 0.21997154929083784, -0.23836134234680978, 0.004746687707779774, 0.007530384631389261, -0.10955799640786414, null, -0.1765821761271682, -0.1850942397507945], [0.042679031654607055, -0.052144978191701497, -0.054615051748212066, -0.05262654232535161, 0.21997154929083784, 1.0, -0.21114546329740214, -0.029766924616865947, 0.013741206803827805, -0.030089307702698295, null, 0.031810717962519525, -0.06839939834495543], [-0.11201795434313827, 0.06006146384146293, 0.0639904536477944, 0.06438668437139708, -0.23836134234680978, -0.21114546329740214, 1.0, -0.013284184382848195, 0.057587102822704746, 0.04481900330504455, null, 0.24529656019562163, 0.20383007359658112], [-0.10753388444435509, -0.021431968683280594, -0.021755150282697804, -0.021812437984530315, 0.004746687707779774, -0.029766924616865947, -0.013284184382848195, 1.0, -0.053266429663612794, -0.0062426171353349175, null, -0.05594830852090013, -0.01624167743898845], [-0.0006362831919527673, -0.08284166161729371, -0.09010514637742674, -0.0889315774941549, 0.007530384631389261, 0.013741206803827805, 0.057587102822704746, -0.053266429663612794, 1.0, -0.03312582029293294, null, 0.06382326723926557, 0.0734186721820231], [0.07461164078418801, 0.07018162145034698, 0.05998191570492083, 0.05949697567659089, -0.10955799640786414, -0.030089307702698295, 0.04481900330504455, -0.0062426171353349175, -0.03312582029293294, 1.0, null, 0.18902362601605371, 0.14484118491158215], [null, null, null, null, null, null, null, null, null, null, null, null, null], [-0.12213711472985694, 0.4182830849260688, 0.392998163266371, 0.3892995109632348, -0.1765821761271682, 0.031810717962519525, 0.24529656019562163, -0.05594830852090013, 0.06382326723926557, 0.18902362601605371, null, 1.0, 0.8478117199537683], [-0.1282498884315512, 0.3907448692170001, 0.36686044934091194, 0.3645704478386024, -0.1850942397507945, -0.06839939834495543, 0.20383007359658112, -0.01624167743898845, 0.0734186721820231, 0.14484118491158215, null, 0.8478117199537683, 1.0]]}],
#                         {},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('27ad0ed3-e247-403c-99fa-2de594839415');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
